# %% [markdown]
# <h1><center>
#
# </center></h1>
# <font size="6"><center>
# EIE 401
# PROCESAMIENTO DIGITAL MULTIMEDIA
# </center></font>

# %% [markdown]
# <center><h2>Actividad 7</h2></center>
# <center><h3>Image</h3></center>
# <center><h3>Profesor: Jorge Cardenas</h3></center>
#
# <center><h3>Por: José Alvarado Espinoza</h3></center>
# <center><h5>Pontificia Universidad Catolica de Valparaiso</h5></center>

# %%
# !pip install opencv-python
# !pip install torch

# %% [markdown]
# ## 0. Cargar la imagen desde el Github

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import urllib.request

# URL de la imagen
url_imagen = "https://raw.githubusercontent.com/kationj/EIE-401JEAE_Actividades/main/Actividad_7/Imagen_actividad_7.png"

# Descargar la imagen desde la URL
response = urllib.request.urlopen(url_imagen)
imagen_arr = np.asarray(bytearray(response.read()), dtype=np.uint8)
response.close()

# Cargar la imagen con cv2
imagen_7 = cv2.imdecode(imagen_arr, cv2.IMREAD_COLOR)

# Convertir la imagen de BGR a RGB
imagen_7_rgb = cv2.cvtColor(imagen_7, cv2.COLOR_BGR2RGB)

# Mostrar la imagen
plt.imshow(imagen_7)
plt.axis("off")
plt.show()

# Mostrar la imagen
plt.imshow(imagen_7_rgb)
plt.axis("off")
plt.show()

# Guardar la imagen en el formato original BGR
cv2.imwrite('imagen_7.png', imagen_7)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import urllib.request

# URL de la imagen
url_imagen = "https://raw.githubusercontent.com/kationj/EIE-401JEAE_Actividades/main/Actividad_7/Imagen_gatos.jpeg"

# Descargar la imagen desde la URL
response = urllib.request.urlopen(url_imagen)
imagen_arr = np.asarray(bytearray(response.read()), dtype=np.uint8)
response.close()

# Cargar la imagen con cv2
imagen_7 = cv2.imdecode(imagen_arr, cv2.IMREAD_COLOR)

# Convertir la imagen de BGR a RGB
imagen_7_rgb = cv2.cvtColor(imagen_7, cv2.COLOR_BGR2RGB)

# Mostrar la imagen
plt.imshow(imagen_7)
plt.axis("off")
plt.show()

# Mostrar la imagen
plt.imshow(imagen_7_rgb)
plt.axis("off")
plt.show()

# Guardar la imagen en el formato original BGR
cv2.imwrite('Imagen_gatos.jpeg', imagen_7)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import urllib.request

# URL de la imagen
url_imagen = "https://raw.githubusercontent.com/kationj/EIE-401JEAE_Actividades/main/Actividad_7/Imagen_bin.png"

# Descargar la imagen desde la URL
response = urllib.request.urlopen(url_imagen)
imagen_arr = np.asarray(bytearray(response.read()), dtype=np.uint8)
response.close()

# Cargar la imagen con cv2
imagen_7 = cv2.imdecode(imagen_arr, cv2.IMREAD_COLOR)

# Convertir la imagen de BGR a RGB
imagen_7_rgb = cv2.cvtColor(imagen_7, cv2.COLOR_BGR2RGB)

# Mostrar la imagen
plt.imshow(imagen_7)
plt.axis("off")
plt.show()

# Mostrar la imagen
plt.imshow(imagen_7_rgb)
plt.axis("off")
plt.show()

# Guardar la imagen en el formato original BGR
cv2.imwrite('Imagen_bin.png', imagen_7)
# Out:
# True

# %% [markdown]
# ## 1. Operaciones usando Pytorch y OpenCV
#
# ### 1.1 Instala Numpy, Pytorch y OpenCV:
# - Carga una imagen desde un archivo con extensión JPG, usando numpy, pytorch y opencv.
# - Presenta la imagen
# - Transforma la imagen de color a escala de grises usando cada uno de los paquetes
# - Guarda la imagen nueva.
# - Presenta la imagen transformada en el notebook.
#
# <p align="justify">
# Asegurate de presentar adecuandamente la imagen, usando Matplotlib u otro medio de ploteo.

# %%
"""Cargar imagen con numpy"""
import numpy as np

# Cargar la imagen con OpenCV
imagen_ruta = "imagen_7.png"
imagen_cv2 = cv2.imread(imagen_ruta)

# Cargar la imagen con Numpy
imagen_np = np.array(cv2.imread(imagen_ruta))

# Convertir a escala de grises con Numpy
imagen_gris_np = np.dot(imagen_np[..., :3], [0.299, 0.587, 0.114])

# Mostrar la imagen en escala de grises con Numpy
plt.imshow(imagen_gris_np, cmap='gray')
plt.axis('off')
plt.title('Imagen en Escala de Grises (Numpy)')
plt.show()

# Guardar la imagen en escala de grises con Numpy
cv2.imwrite('imagen_gris_np.jpg', imagen_gris_np)
# Out:
# True

# %%
"""Cargar imagen con Pytorch"""
import torch
# Convertir la imagen a tensor de PyTorch
imagen_tensor = torch.from_numpy(imagen_np).permute(2, 0, 1).float() / 255.0

# Convertir a escala de grises con PyTorch
# Los pesos corresponden a la conversión a escala de grises
pesos = torch.tensor([0.299, 0.587, 0.114]).view(3, 1, 1)
imagen_gris_tensor = torch.sum(imagen_tensor * pesos, dim=0)

# Convertir de tensor a Numpy para mostrar y guardar
imagen_gris_tensor_np = imagen_gris_tensor.numpy()

# Mostrar la imagen en escala de grises con PyTorch
plt.imshow(imagen_gris_tensor_np, cmap='gray')
plt.axis('off')
plt.title('Imagen en Escala de Grises (PyTorch)')
plt.show()

# Guardar la imagen en escala de grises con PyTorch
cv2.imwrite('imagen_gris_tensor.jpg', (imagen_gris_tensor_np * 255).astype(np.uint8))
# Out:
# True

# %%
"""Cargar imagen con OpenCV"""
import cv2
# Convertir a escala de grises con OpenCV
imagen_gris_cv2 = cv2.cvtColor(imagen_cv2, cv2.COLOR_BGR2GRAY)

# Mostrar la imagen en escala de grises con OpenCV
plt.imshow(imagen_gris_cv2, cmap='gray')
plt.axis('off')
plt.title('Imagen en Escala de Grises (OpenCV)')
plt.show()

# Guardar la imagen en escala de grises con OpenCV
cv2.imwrite('imagen_gris_cv2.jpg', imagen_gris_cv2)
# Out:
# True

# %% [markdown]
# ## 2. Multiples operaciones con tensores
# ### ¡USA LA IMAGEN ADJUNTA image.png!

# %% [markdown]
# #### 2.1 Aplica una transformación puntual. Modifica el valor de los pixeles considerando un valor de umbral (threshold). la función de treshold debe ser una rampa con una pendiente dada (tu defines el valor de la pendiente) y cuyo valor mínimo será 0 y el máximo será 255 (valores típicos de los pixeles).

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def apply_threshold_ramp(image, threshold, slope):
    # Crear una función de rampa con la pendiente y el umbral dados
    def ramp(x):
        return np.clip(slope * (x - threshold) + 127.5, 0, 255)
    
    # Aplicar la función de rampa a cada píxel de la imagen
    transformed_image = ramp(image)
    
    return transformed_image.astype(np.uint8)

# Cargar una imagen en escala de grises
image = cv2.imread("imagen_7.png", cv2.IMREAD_GRAYSCALE)

# Definir el umbral y la pendiente
threshold = 55
slope = 1.5

# Aplicar la transformación
transformed_image = apply_threshold_ramp(image, threshold, slope)

# Mostrar la imagen original y la transformada
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Imagen Original')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Imagen Transformada')
plt.imshow(transformed_image, cmap='gray')
plt.axis('off')

plt.show()

# %% [markdown]
# #### 2.2 Aplica una transformación en la vecindad.
# - Debes hacer una vecindad con dimensiones de 5x5 pixeles.
# - Aplica la transformación de tal forma que los pixeles cambien para tener el valor correspondiente al máximo de todos los vecinos.
# - Debes hacer la misma operación a lo largo y ancho de toda la imagen. ESto implica, de forma iterativa, recorrer la imagen.

# %%
"""
Para aplicar una transformación en la vecindad con dimensiones de 5x5 píxeles y ajustar cada píxel
para que tome el valor máximo de todos sus vecinos, estamos hablando de una operación de filtrado
que se conoce como dilatación en procesamiento de imágenes. Esta operación pertenece a la categoría 
de morfología matemática.
"""

import cv2
import numpy as np
import matplotlib.pyplot as plt

def apply_max_filter(image, kernel_size):
    # Aplicar la operación de dilatación
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    transformed_image = cv2.dilate(image, kernel, iterations=1)
    
    return transformed_image

# Cargar una imagen en escala de grises
image = cv2.imread("imagen_7.png", cv2.IMREAD_GRAYSCALE)

# Definir el tamaño de la vecindad (kernel_size)
kernel_size = 5

# Aplicar la transformación
transformed_image = apply_max_filter(image, kernel_size)

# Mostrar la imagen original y la transformada
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Imagen Original')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Imagen Transformada')
plt.imshow(transformed_image, cmap='gray')
plt.axis('off')

plt.show()

# %% [markdown]
# #### 2.3 Aplica transformación de intensidad
# ![image.png](attachment:image.png)
# - Debes hacer una vecindad con dimensiones de 10x10 pixeles.
# - Aplica la transformación que aparece en la ecuación de tal forma que los pixeles cambien dependiendo de la posición (r) y el coeficiente c (de tu elección).
# - Debes hacer la misma operación a lo largo y ancho de toda la imagen. ESto implica, de forma iterativa, recorrer la imagen.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def log_transform(image, kernel_size, c):
    # Obtener las dimensiones de la imagen
    rows, cols = image.shape
    
    # Crear una imagen de salida
    transformed_image = np.zeros((rows, cols), dtype=np.float32)
    
    # Definir el radio máximo
    max_r = kernel_size // 2
    
    # Iterar sobre cada píxel de la imagen
    for i in range(max_r, rows - max_r):
        for j in range(max_r, cols - max_r):
            # Extraer la vecindad de 10x10
            neighborhood = image[i-max_r:i+max_r+1, j-max_r:j+max_r+1]
            
            # Aplicar la transformación logarítmica a cada píxel de la vecindad
            for m in range(neighborhood.shape[0]):
                for n in range(neighborhood.shape[1]):
                    r = neighborhood[m, n]
                    transformed_image[i, j] = c * np.log(1 + r)
    
    # Normalizar la imagen transformada a valores entre 0 y 255
    transformed_image = np.clip(transformed_image, 0, 255)
    transformed_image = transformed_image.astype(np.uint8)
    
    return transformed_image

# Cargar una imagen en escala de grises
image = cv2.imread("imagen_7.png", cv2.IMREAD_GRAYSCALE)

# Definir el tamaño de la vecindad y el coeficiente c
kernel_size = 10
c = 3  # Puede ajustarse según sea necesario

# Aplicar la transformación
transformed_image = log_transform(image, kernel_size, c)

# Mostrar la imagen original y la transformada
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Imagen Original')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Imagen Transformada')
plt.imshow(transformed_image, cmap='gray')
plt.axis('off')

plt.show()

# %% [markdown]
# #### 2.4 Operación con Kernel
# - Realiza tres operaciones de convolución en cascada.
# - Utiliza torch nn.Conv2d
# - Debes calcular el stride, padding y demás parámetros para que obtengas 16 canales de salida.
# - Muestra una imagen de cada canal resultante de la convolución.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Función para mostrar una imagen
def show_image(image, title=''):
    plt.imshow(image, cmap='gray')
    plt.title(title)
    plt.axis('off')
    plt.show()

# Cargar una imagen en escala de grises y normalizarla
image = cv2.imread("imagen_7.png", cv2.IMREAD_GRAYSCALE)
image = image.astype(np.float32) / 255.0

# Convertir la imagen a un tensor de PyTorch
image_tensor = torch.from_numpy(image).unsqueeze(0).unsqueeze(0)  # Shape: (1, 1, H, W)

# Definir una secuencia de capas de convolución
class ConvCascade(nn.Module):
    def __init__(self):
        super(ConvCascade, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(16, 16, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        return x

# Inicializar el modelo y aplicar la convolución en cascada
model = ConvCascade()
output = model(image_tensor)

# Mostrar cada uno de los 16 canales resultantes
output_np = output.detach().numpy().squeeze()  # Shape: (16, H, W)

for i in range(output_np.shape[0]):
    show_image(output_np[i], title=f'Canal {i+1}')

# %% [markdown]
# ## 3. Realiza la inversión de imagen
#
# ### 3.1 Utilizando estrictamente numpy, busca y usa una imagen binaria y realizar la inversión de dicha imagen.
# ### Recuerda adjuntar la imagen a la entrega de tu trabajo.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Cargar la imagen binaria en escala de grises
Imagen_bin = cv2.imread("Imagen_bin.png", cv2.IMREAD_GRAYSCALE)

# Asegurarse de que la imagen sea binaria (valores 0 y 255)
# Invertir la imagen binaria: cambiar 0 a 255 y 255 a 0
Imagen_bin_invertida = 255 - Imagen_bin

# Mostrar la imagen original y la imagen invertida
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Imagen Binaria Original')
plt.imshow(Imagen_bin, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Imagen Binaria Invertida')
plt.imshow(Imagen_bin_invertida, cmap='gray')
plt.axis('off')

plt.show()

# Guardar la imagen invertida
cv2.imwrite('Imagen_bin_invertida.jpg', Imagen_bin_invertida)
# Out:
# True

# %% [markdown]
# ### 3.1 Usando Pytorch y opencv, realiza la inversión de la misma imagen.

# %%
import cv2
import matplotlib.pyplot as plt

# Cargar la imagen binaria en escala de grises
Imagen_bin = cv2.imread("Imagen_bin.png", cv2.IMREAD_GRAYSCALE)

# Verificar que la imagen está cargada correctamente
if Imagen_bin is None:
    raise ValueError("No se pudo cargar la imagen. Verifica el path.")

# Invertir la imagen binaria
Imagen_bin_invertida = cv2.bitwise_not(Imagen_bin)

# Mostrar la imagen original y la imagen invertida
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Imagen Binaria Original')
plt.imshow(Imagen_bin, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Imagen Binaria Invertida')
plt.imshow(Imagen_bin_invertida, cmap='gray')
plt.axis('off')

plt.show()

# Guardar la imagen invertida
cv2.imwrite('Imagen_bin_invertida.jpg', Imagen_bin_invertida)
# Out:
# True

# %%
import torch
import matplotlib.pyplot as plt
from torchvision import transforms
from PIL import Image

# Cargar la imagen binaria utilizando PIL y convertirla a tensor
image = Image.open("Imagen_bin.png").convert('L')
transform = transforms.ToTensor()
tensor_image = transform(image)

# Verificar que la imagen está cargada correctamente
if tensor_image is None:
    raise ValueError("No se pudo cargar la imagen. Verifica el path.")

# Invertir la imagen binaria: cambiar 0 a 1 y 1 a 0
tensor_image_inverted = 1 - tensor_image

# Convertir el tensor invertido de vuelta a imagen PIL
transform_to_pil = transforms.ToPILImage()
inverted_image = transform_to_pil(tensor_image_inverted)

# Mostrar la imagen original y la imagen invertida
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Imagen Binaria Original')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Imagen Binaria Invertida')
plt.imshow(inverted_image, cmap='gray')
plt.axis('off')

plt.show()

# Guardar la imagen invertida
inverted_image.save('Imagen_bin_invertida_pytorch.jpg')

# %% [markdown]
# ## 4. Segmentación de imagen
# #### 4.1 Realiza un algoritmo para dividir una imagen con 3 canales RGB de 512x512, en parches (secciones) de 16x16. Presenta cada parche generado de la imagen.
# El algoritmo debe tolerar el cambio de imagen por una de menor tamano (128, 64). Claramente, en cada caso el número de parches será menor.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def segmentar_imagen(imagen, size=16):
    parches = []
    altura, ancho, _ = imagen.shape
    
    for y in range(0, altura, size):
        for x in range(0, ancho, size):
            parche = imagen[y:y+size, x:x+size]
            parches.append(parche)
    
    return parches

# Cargar la imagen
imagen = cv2.imread("Imagen_gatos.jpeg")

# Verificar que la imagen está cargada correctamente
if imagen is None:
    raise ValueError("No se pudo cargar la imagen. Verifica el path.")

# Segmentar la imagen en parches de 16x16
parches = segmentar_imagen(imagen, size=16)

# Mostrar cada parche generado
num_parches = len(parches)
num_columnas = 8  # Para mostrar 8 parches por fila
num_filas = num_parches // num_columnas + (num_parches % num_columnas > 0)

plt.figure(figsize=(10, 10))
for i, parche in enumerate(parches):
    plt.subplot(num_filas, num_columnas, i + 1)
    plt.imshow(cv2.cvtColor(parche, cv2.COLOR_BGR2RGB))
    plt.axis('off')

plt.show()

# %% [markdown]
# ## 5. Referencias
# <p align="justify">
#
# [OpenCV] https://docs.opencv.org/4.x/d7/da8/tutorial_table_of_content_imgproc.html
#
# [inversion] https://medium.com/analytics-vidhya/inverting-an-image-using-numpys-broadcasting-method-1f5beb7f9fa5#:~:text=In%20order%20to%20invert%20the,negation)%20operation%20to%20the%20image.
